# %%
import mytorch

# %%
a = mytorch.Tensor([1], True) * 2 # a = 2
b = a + 3 # b = 5
c = b / 4 # c = 1.25
d = a + c # d = 3.25

# %%
input_tensor = mytorch.ones(1, requires_grad=True)
topo = mytorch.build_topo(d)
G = mytorch.build_graph(topo)
mytorch.plot_graph(G)
